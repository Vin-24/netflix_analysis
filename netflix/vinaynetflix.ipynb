# %% [markdown]
# # netflix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'E:\vinay\dataset\netflix\netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Task.1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#df.isnull().sum()

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# ## there is no duplicate data in the datarecord

# %% [markdown]
# # Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
n1 = df.isnull()
n1
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(data = n1)
# Out:
# <Axes: >

# %% [markdown]
# ### Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.loc[df['director'] == 'david fincher']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.loc[df['title'] == 'House of Cards']
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Answer-
#   - show-id == s1060
#   - director=david fincher(source-internet)

# %% [markdown]
# ### Q. 2) In which year the highest number of TV Shows & Movies were released? Show with Bar Graph.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df["release_year"].value_counts().head(10).plot.barh(figsize=(30,20))
plt.show()

# %%
df.release_year
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2007
# 8803    2018
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 8807, dtype: int64

# %% [markdown]
# ### Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df.type
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
f1=df["type"].value_counts()
f1
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
plt.bar(f1.index, f1.values)
plt.xlabel('types')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Q. 4) Show all the Movies that were released in the year 2000.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.loc[df['release_year'] == 2000]
# Out:
#      show_id     type                                              title  \
# 180     s181    Movie                 The Nutty Professor II: The Klumps
# 350     s351    Movie                                      Space Cowboys
# 359     s360    Movie                       The Original Kings of Comedy
# 566     s567    Movie                                   Charlie's Angels
# 593     s594    Movie                                           Snow Day
# 779     s780    Movie                                  Battlefield Earth
# 952     s953    Movie                               The Whole Nine Yards
# 2173   s2174  TV Show                                             Moesha
# 3472   s3473    Movie                        Rugrats in Paris: The Movie
# 4545   s4546    Movie             Monty Python: Before the Flying Circus
# 4723   s4724    Movie                                               Fiza
# 4956   s4957    Movie                        Phir Bhi Dil Hai Hindustani
# ...

# %%
h=df[df["release_year"]==2000].type
h.value_counts()
# Out:
# Movie      33
# TV Show     4
# Name: type, dtype: int64

# %% [markdown]
# ### there are 33 movies and 4 tv show released in 2000

# %% [markdown]
# ## Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.loc[df['country'] == 'India'].title
# Out:
# 4                        Kota Factory
# 24                              Jeans
# 39                       Chhota Bheem
# 50                      Dharmakshetra
# 66      Raja Rasoi Aur Anya Kahaniyan
#                     ...
# 8773              Yanda Kartavya Aahe
# 8775                  Yeh Meri Family
# 8798                         Zed Plus
# 8799                            Zenda
# 8806                           Zubaan
# Name: title, Length: 972, dtype: object

# %% [markdown]
# ## Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df["director"].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# ### here are the top 10 directors

# %% [markdown]
# ### Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
a=df.loc[df['listed_in'] == 'Comedies']
a
#a.value_counts()
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
a.type.value_counts()
# Out:
# Movie    110
# Name: type, dtype: int64

# %%
a.loc[a['country'] == 'United Kingdom']
# Out:
#      show_id   type                                              title  \
# 3332   s3333  Movie                                 Christmas Survival
# 4544   s4545  Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4547   s4548  Movie           Monty Python: Live at The Hollywood Bowl
# 4554   s4555  Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 6576   s6577  Movie                Dead in a Week (Or Your Money Back)
# 6779   s6780  Movie                                  For Love or Money
# 8201   s8202  Movie                            The Bad Education Movie
# 8536   s8537  Movie                                  The Trip to Spain
#
#                            director  \
# 3332                  James Dearden
# 4544                      Eric Idle
# 4547  Terry Hughes, Ian MacNaughton
# 4554                Ian MacNaughton
# 6576                    Tom Edmunds
# 6779                    Mark Murphy
# 8201                 Elliot Hegarty
# ...

# %% [markdown]
# ### these are all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom

# %% [markdown]
# ## Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
p=df.loc[df['type'] == 'TV Show'].country
p
# Out:
# 1                                        South Africa
# 2                                                 NaN
# 3                                                 NaN
# 4                                               India
# 5                                                 NaN
#                             ...
# 8795                                    Japan, Canada
# 8796                                           Turkey
# 8797    United States, France, South Korea, Indonesia
# 8800                                         Pakistan
# 8803                                              NaN
# Name: country, Length: 2676, dtype: object

# %%
p.value_counts().head(5)
# Out:
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Name: country, dtype: int64

# %% [markdown]
# ### hence united states have highest number of tv shows

# %% [markdown]
# ### south africa has the highest no of Tv shows

# %% [markdown]
# ## Q. 12) How can we sort the dataset by Year ?

# %%
df.sort_values(by='release_year')
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %% [markdown]
# ### hence we have sorted the dataframe by year

# %% [markdown]
# ## Q. 9) What are the different Ratings defined by Netflix ?
#   - Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?
#   - Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df.rating.value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %% [markdown]
# ### here are 17 differnt types of rating defined by netflix

# %%
q=df.loc[df["rating"] == 'TV-14']
q
# Out:
#      show_id     type                                            title  \
# 8         s9  TV Show                    The Great British Baking Show
# 18       s19    Movie                                        Intrusion
# 20       s21  TV Show  Monsters Inside: The 24 Faces of Billy Milligan
# 21       s22  TV Show                           Resurrection: Ertugrul
# 24       s25    Movie                                            Jeans
# ...      ...      ...                                              ...
# 8772   s8773    Movie                            Yamla Pagla Deewana 2
# 8774   s8775    Movie                                        يوم الدين
# 8794   s8795    Movie                                           اشتباك
# 8799   s8800    Movie                                            Zenda
# 8806   s8807    Movie                                           Zubaan
#
#              director                                               cast  \
# ...

# %%
d=q.loc[q["country"]=='Canada'].type
d.value_counts()
# Out:
# Movie      13
# TV Show    13
# Name: type, dtype: int64

# %% [markdown]
# ### there are 13 movie which got the 'TV-14' rating, in Canada

# %% [markdown]
# ### Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
l=df.loc[df["rating"] == 'R']
l
# Out:
#      show_id   type                        title  \
# 46       s47  Movie                   Safe House
# 48       s49  Movie                 Training Day
# 81       s82  Movie                         Kate
# 122     s123  Movie                   In the Cut
# 131     s132  Movie  Blade Runner: The Final Cut
# ...      ...    ...                          ...
# 8765   s8766  Movie                           XX
# 8768   s8769  Movie            Y Tu Mamá También
# 8791   s8792  Movie                  Young Adult
# 8802   s8803  Movie                       Zodiac
# 8804   s8805  Movie                   Zombieland
#
#                                                director  \
# 46                                      Daniel Espinosa
# 48                                        Antoine Fuqua
# 81                                Cedric Nicolas-Troyan
# 122                                        Jane Campion
# 131                                        Ridley Scott
# ...

# %%
l[(l["type"] == 'TV Show')&(l["release_year"]> 2018)].shape[0]
# Out:
# 0

# %%
#df[(df['type'] == 'TV Show')&(df['rating'] == 'R')&(df['release_year'] > 2018)].shape[0]

# %% [markdown]
# ### there are 0 movies that got the 'R' rating, after year 2018

# %% [markdown]
# ## Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df2=df.copy()

# %%
df2.dropna(inplace=True)

# %%
df2['New_Cast']=df2['cast'].apply(lambda a: str(a.split(".")) if a else np.nan)

# %%
df2['New_Cast']=df2['New_Cast'].apply(lambda a: 'Tom Cruise' if 'Tom Cruise' in a else a)

# %%
df2[df2['New_Cast']=='Tom Cruise']
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description    New_Cast
# 341   Through chance, history and divine interventio...  Tom Cruise
# 1254  Motivated by money, a selfish workaholic seeki...  Tom Cruise

# %% [markdown]
# ### there are two Movie in which tom cruise was cast

# %% [markdown]
# ## Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is
# ##    'TV Show' & Type is 'Kids' TV'.** Task. 1) Is there any Duplicate Record in this dataset
# ##    ? If yes, then remove the duplicate records."Country is United Kingdom".

# %%
df[((df.type == 'Movie')&(df['listed_in'].str.contains('Dramas', na = False)))|((df.type == 'TV Show')&(df['listed_in'].str.contains("'Kids'TV", na = False)))]
# Out:
#      show_id   type                           title  \
# 7         s8  Movie                         Sankofa
# 9        s10  Movie                    The Starling
# 12       s13  Movie                    Je Suis Karl
# 30       s31  Movie                 Ankahi Kahaniya
# 35       s36  Movie  The Father Who Moves Mountains
# ...      ...    ...                             ...
# 8798   s8799  Movie                        Zed Plus
# 8799   s8800  Movie                           Zenda
# 8801   s8802  Movie                         Zinzana
# 8802   s8803  Movie                          Zodiac
# 8806   s8807  Movie                          Zubaan
#
#                                                director  \
# 7                                          Haile Gerima
# 9                                        Theodore Melfi
# 12                                  Christian Schwochow
# 30    Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# ...

# %% [markdown]
# ### here are instances where Category is 'Movie' and Type is 'Dramas'

# %% [markdown]
# ## ques 10:-

# %%
df.sort_values(by = 'duration', ascending= False)
# Out:
#      show_id     type                                  title  \
# 1329   s1330    Movie  The Misadventures of Hedi and Cokeman
# 6278   s6279    Movie                               Being AP
# 952     s953    Movie                   The Whole Nine Yards
# 6141   s6142    Movie                       American Hangman
# 929     s930    Movie                Dead Again in Tombstone
# ...      ...      ...                                    ...
# 6556   s6557  TV Show                          Dance Academy
# 2945   s2946  TV Show             Cagaster of an Insect Cage
# 5541   s5542    Movie                        Louis C.K. 2017
# 5794   s5795    Movie                  Louis C.K.: Hilarious
# 5813   s5814    Movie   Louis C.K.: Live at the Comedy Store
#
#                director                                               cast  \
# 1329       Julien Royal  Hedi Bouchenafa, Nassim Lyes, Fred Testot, Jul...
# 6278      Anthony Wonke                                         Tony McCoy
# ...
